# %%
import numpy as np

# %%
A = np.array([[4,1],[5,2]])
B = np.array([[1,-4],[5,2]])

# %%
A[0]@B[0]
# Out:
# 0

# %%
C = D = np.random.rand(8,8)
print(G.shape)
E = np.zeros_like(C[...,0])
# Out:
# (8, 8, 2)

# %%
I = 0
for i in range(C.shape[0]):
    for j in range(C.shape[1]):
        E[i,j] = C[i,j]@D[i,j]
        C += 1
        print("E Val is: {}\nIter: {}\n\n".format(E[i,j], I))
# Out:
# E Val is: 0.07333287317997202
# Iter: 0
#
#
# E Val is: 4.696065997258388
# Iter: 0
#
#
# E Val is: 12.02538135891306
# Iter: 0
#
#
# E Val is: 23.430617710302055
# Iter: 0
#
#
# E Val is: 40.7074938731686
# Iter: 0
#
#
# E Val is: 58.40550159800842
# Iter: 0
#
#
# E Val is: 81.80979464418895
# Iter: 0
#
#
# E Val is: 117.09612112787042
# Iter: 0
#
#
# E Val is: 136.20446521155435
# Iter: 0
#
#
# E Val is: 169.70998689682256
# Iter: 0
#
#
# E Val is: 226.69348345082653
# Iter: 0
#
#
# E Val is: 255.5839992475424
# Iter: 0
#
#
# E Val is: 321.1487163054827
# Iter: 0
#
#
# E Val is: 363.9420212431663
# Iter: 0
#
#
# E Val is: 415.6729466084683
# Iter: 0
#
#
# E Val is: 479.25087815415725
# Iter: 0
#
#
# E Val is: 524.0446940678298
# Iter: 0
#
#
# E Val is: 612.4068743740363
# Iter: 0
#
#
# E Val is: 694.4345814498629
# Iter: 0
#
#
# E Val is: 755.1080003097737
# Iter: 0
#
#
# E Val is: 835.5197532609002
# Iter: 0
#
#
# E Val is: 914.0230187909765
# Iter: 0
#
#
# ...

# %%
E
# Out:
# array([[7.33328732e-02, 4.69606600e+00, 1.20253814e+01, 2.34306177e+01,
#         4.07074939e+01, 5.84055016e+01, 8.18097946e+01, 1.17096121e+02],
#        [1.36204465e+02, 1.69709987e+02, 2.26693483e+02, 2.55583999e+02,
#         3.21148716e+02, 3.63942021e+02, 4.15672947e+02, 4.79250878e+02],
#        [5.24044694e+02, 6.12406874e+02, 6.94434581e+02, 7.55108000e+02,
#         8.35519753e+02, 9.14023019e+02, 9.87867353e+02, 1.09211200e+03],
#        [1.18379152e+03, 1.32591893e+03, 1.40026209e+03, 1.47493819e+03,
#         1.66340168e+03, 1.77534215e+03, 1.90079864e+03, 1.93703374e+03],
#        [2.09644158e+03, 2.28738292e+03, 2.37691274e+03, 2.55450896e+03,
#         2.64773987e+03, 2.80252003e+03, 3.03378129e+03, 3.15269280e+03],
#        [3.24847929e+03, 3.44843869e+03, 3.59020807e+03, 3.76600370e+03,
#         3.95895724e+03, 4.16951933e+03, 4.32223235e+03, 4.47272852e+03],
#        [4.72325806e+03, 4.85253515e+03, 5.09480227e+03, 5.34625498e+03,
# ...
